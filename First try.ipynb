# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv("military_expenditure.csv")

# %%
train
# Out:
#            country iso3c iso2c  year  Military expenditure (current USD)  \
# 0      Afghanistan   AFG    AF  1970                        2.939586e+06
# 1      Afghanistan   AFG    AF  1971                                 NaN
# 2      Afghanistan   AFG    AF  1972                                 NaN
# 3      Afghanistan   AFG    AF  1973                        3.341272e+06
# 4      Afghanistan   AFG    AF  1974                        3.581366e+06
# ...            ...   ...   ...   ...                                 ...
# 13561     Zimbabwe   ZWE    ZW  2016                        3.580650e+08
# 13562     Zimbabwe   ZWE    ZW  2017                        3.405220e+08
# 13563     Zimbabwe   ZWE    ZW  2018                        4.203640e+08
# 13564     Zimbabwe   ZWE    ZW  2019                        5.469390e+08
# 13565     Zimbabwe   ZWE    ZW  2020                                 NaN
#
#        Military expenditure (% of general government expenditure)  \
# ...

# %%
train.var()
# Out:
# C:\Users\l\AppData\Local\Temp\ipykernel_9768\3617257294.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   train.var()
# year                                                          2.166826e+02
# Military expenditure (current USD)                            2.023754e+22
# Military expenditure (% of general government expenditure)    3.658965e+01
# Military expenditure (% of GDP)                               8.537318e+00
# dtype: float64

# %%
train.corr()
# Out:
#                                                         year  \
# year                                                1.000000
# Military expenditure (current USD)                  0.143134
# Military expenditure (% of general government e... -0.191886
# Military expenditure (% of GDP)                    -0.236705
#
#                                                     Military expenditure (current USD)  \
# year                                                                          0.143134
# Military expenditure (current USD)                                            1.000000
# Military expenditure (% of general government e...                           -0.027606
# Military expenditure (% of GDP)                                               0.002617
#
#                                                     Military expenditure (% of general government expenditure)  \
# year                                                                                        -0.191886
# ...

# %%
train[feat_cols]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 train[feat_cols]
#
# NameError: name 'feat_cols' is not defined

# %%
from glob import glob
import cv2
